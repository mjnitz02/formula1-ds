# %%
from formula1.dataset import ErgastDataset

# %%
import pandas as pd

# %%
from formula1.ergast import QueryRaceResults
QueryRaceResults(season="current", race=1).call()
# Out:
#    number position positionText points  \
# 0      44        1            1     25
# 1      33        2            2     18
# 2      77        3            3     16
# 3       4        4            4     12
# 4      11        5            5     10
# 5      16        6            6      8
# 6       3        7            7      6
# 7      55        8            8      4
# 8      22        9            9      2
# 9      18       10           10      1
# 10      7       11           11      0
# 11     99       12           12      0
# 12     31       13           13      0
# 13     63       14           14      0
# 14      5       15           15      0
# 15     47       16           16      0
# 16     10       17           17      0
# 17      6       18           18      0
# 18     14       19            R      0
# 19      9       20            R      0
#
#                                                Driver  \
# 0   {'driverId': 'hamilton', 'permanentNumber': '4...
# ...

# %%
df
# Out:
#    number position positionText points  \
# 0      44        1            1     25
# 1      33        2            2     18
# 2      77        3            3     16
# 3       4        4            4     12
# 4      11        5            5     10
# 5      16        6            6      8
# 6       3        7            7      6
# 7      55        8            8      4
# 8      22        9            9      2
# 9      18       10           10      1
# 10      7       11           11      0
# 11     99       12           12      0
# 12     31       13           13      0
# 13     63       14           14      0
# 14      5       15           15      0
# 15     47       16           16      0
# 16     10       17           17      0
# 17      6       18           18      0
# 18     14       19            R      0
# 19      9       20            R      0
#
#                                                Driver  \
# 0   {'driverId': 'hamilton', 'permanentNumber': '4...
# ...

# %% [markdown]
# dataset = ErgastDataset()
# dataset.build_dataset()
